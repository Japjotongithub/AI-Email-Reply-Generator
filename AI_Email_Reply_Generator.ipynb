# %% [markdown]
# <a href="https://colab.research.google.com/github/Japjotongithub/AI-Email-Reply-Generator/blob/main/AI_Email_Reply_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install openai

# %%
# !pip install -U google-generativeai

# %%
import google.generativeai as genai

# 🔑 Paste your API key here
genai.configure(api_key="AIzaSyD2IwzboFt_mARe4KMKHEkCro-MAv3uZLw")

# Model (works in Colab)
model = genai.GenerativeModel("gemini-flash-latest")

def generate_reply(email_text, tone="formal"):
    prompt = f"""
    Write a professional email reply.

    Tone: {tone}

    Email:
    {email_text}

    Keep it polite, clear, and short.
    """

    response = model.generate_content(prompt)
    return response.text


# Example input
email = "I will not be able to attend the meeting tomorrow. Please share updates."

reply = generate_reply(email)

print("Generated Reply:\n")
print(reply)
# Out:
# Generated Reply:
#
# Subject: Re: [Meeting Name/Subject]
#
# Dear [Name],
#
# Thank you for letting me know. I will ensure that the meeting notes and updates are shared with you afterward.
#
# Best regards,
#
# [Your Name]

# %%
email = "Good afternoon sir.I implemented the ML models for the Life Insurance dataset.This is my progress for now.Do tell me if anything else is required."

reply = generate_reply(email)

print("Generated Reply:\n")
print(reply)
# Out:
# Generated Reply:
#
# Subject: Re: Life Insurance ML Model Implementation
#
# Dear [Name],
#
# Thank you for the update on the ML models for the Life Insurance dataset.
#
# I will review your progress and let you know if any further refinements or additional tasks are required. In the meantime, please ensure that the performance metrics are well-documented.
#
# Best regards,
#
# [Your Name]

# %%
import google.generativeai as genai

# 🔑 Paste your API key here
genai.configure(api_key="AIzaSyD2IwzboFt_mARe4KMKHEkCro-MAv3uZLw")

# Model (works in Colab)
model = genai.GenerativeModel("gemini-flash-latest")

def generate_reply(email_text, tone="formal"):
    prompt = f"""
    Write a professional email reply.

    Tone: {tone}

    Email:
    {email_text}

    Keep it polite, clear, and short.
    """

    response = model.generate_content(prompt)
    return response.text


# Example input
email = """Hello Sir,
This is to inform you that we are running out of storage on our servers.This may cause issues in our ongoing and upcoming projects.

We need either more memory or better cloud services.
I am a new employee so I don't know the exact procedure of approval """

reply = generate_reply(email)

print("Generated Reply:\n")
print(reply)
# Out:
# Generated Reply:
#
# Subject: Regarding Server Storage Capacity and Procurement Process
#
# Dear [Sender Name],
#
# Thank you for bringing the server storage capacity issue to my attention. It is important that we address this promptly to avoid any disruption to our ongoing projects.
#
# To proceed with a request for additional memory or an upgrade to our cloud services, the standard procedure is to [submit a formal request via our internal portal / email the IT Procurement department].
#
# Please draft a brief proposal outlining the specific requirements and estimated costs. I will then review it and guide you through the final approval steps.
#
# Best regards,
#
# [Your Name]
# [Your Title]
